# %% [markdown]
# <a href="https://colab.research.google.com/github/KaioVinycius-coder/LAED/blob/main/Laed(lista_1_%2B).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from random import randint

def creat_vector(t, limi, lims):
   vect = [0] * t

   for i in range(t):
    vect[i] = random.randint(limi, lims)

   return vect

# %% [markdown]
# MAIOR IMPAR

# %%
import random

while True:
  limi = int(input("Diga o limite inferior: "))
  lims = int(input("Diga um limite superior: "))
  t = int(input("Diga o tamanho do vetor: "))

  if(t < 0):
    t = t * -1

  if(limi > lims):
    aux = lims
    lims = limi
    limi = aux
    break

  else:
    break


v = creat_vector(t, limi, lims)
print(v)
ma = 0
for i in range(len(v)):
  if(v[i]%2 != 0):
    if(v[i] > ma):
      ma = v[i]


print(f"Maior elemento ímpar da lista: {ma}")
# Out:
# Diga o limite inferior: 1
# Diga um limite superior: 100
# Diga o tamanho do vetor: 5
# [19, 56, 33, 93, 37]
# Maior elemento ímpar da lista: 93

# %% [markdown]
# SEGUNDO MAIOR IMPAR

# %%
import random

while True:
  limi = int(input("Diga o limite inferior: "))
  lims = int(input("Diga um limite superior: "))
  t = int(input("Diga o tamanho do vetor: "))

  if(t < 0):
    t = t * -1

  if(limi > lims):
    aux = lims
    lims = limi
    limi = aux
    break

  else:
    break


v = creat_vector(t, limi, lims)
print(v)
ma = 0
seg = 0
for i in range(len(v)):
  if(v[i]%2 != 0):
    if(v[i] > ma):
      seg = ma
      ma = v[i]


print(f"Maior elemento ímpar da lista: {ma}, segundo maior: {seg}")
# Out:
# Diga o limite inferior: 1
# Diga um limite superior: 1000
# Diga o tamanho do vetor: 5
# [623, 892, 749, 403, 551]
# Maior elemento ímpar da lista: 749, segundo maior: 623

# %% [markdown]
# ELEMENTOS MAIS PROXIMOS

# %%
import random

while True:
  limi = int(input("Diga o limite inferior: "))
  lims = int(input("Diga um limite superior: "))
  t = int(input("Diga o tamanho do vetor: "))

  if(t < 0):
    t = t * -1

  if(limi > lims):
    aux = lims
    lims = limi
    limi = aux
    break

  else:
    break


v = creat_vector(t, limi, lims)
print(v)

difa = 0
dift = 0
if(v[0] > v[1]):
  difm = v[0] - v[1]
else:
  difm = v[1] - v[0]
x = 0
y = 0

dift = 0

for i in range(len(v)):
  for j in range(i+1, len(v)):
     if(v[i] > v[j]):
      ma = v[i]
      me = v[j]
     else:
      ma = v[j]
      me = v[i]

     difa = ma - me
     if(dift == 0):
      dift = difa
      continue

     if(difa < dift and difa < difm):
        difm = difa
        x = v[i]
        y = v[j]





     dift = difa
     difa = 0

print(f"diferença entre {x} e {y}: {difm}")
# Out:
# Diga o limite inferior: -100
# Diga um limite superior: 100
# Diga o tamanho do vetor: 5
# [-16, -93, -96, 80, 10]
# diferença entre -93 e -96: 3

# %% [markdown]
# IMPAR IMPAR

# %%
import random

while True:
  limi = int(input("Diga o limite inferior: "))
  lims = int(input("Diga um limite superior: "))
  t = int(input("Diga o tamanho do vetor: "))

  if(t < 0):
    t = t * -1

  if(limi > lims):
    aux = lims
    lims = limi
    limi = aux
    break

  else:
    break


v = creat_vector(t, limi, lims)
print(v)

num = 0
nump = 0
repa = 1
repm = 0
ach = 0

for i in range(len(v)):
  if(v[i]%2 != 0):
    num = v[i]

    ach+=1
    for j in range(i+1,len(v)):
      if(num == v[j]):
        repa+=1
        continue

    if(repa >= repm and repa%2 != 0):
        repm = repa
        nump = num

  repa = 1

if(ach > 0):
 print(f"Numero impar que mais repetiu: {nump} que repetiu: {repm} vezes")

else:
  print("Não há impares")
# Out:
# Diga o limite inferior: 3
# Diga um limite superior: 7
# Diga o tamanho do vetor: 18
# [5, 4, 3, 6, 7, 3, 5, 4, 6, 5, 5, 3, 7, 5, 7, 4, 4, 6]
# Numero impar que mais repetiu: 5 que repetiu: 5 vezes

# %% [markdown]
# ALGUEM E O DOBRO

# %%
import random

while True:
  limi = int(input("Diga o limite inferior: "))
  lims = int(input("Diga um limite superior: "))
  t = int(input("Diga o tamanho do vetor: "))

  if(t < 0):
    t = t * -1

  if(limi > lims):
    aux = lims
    lims = limi
    limi = aux
    break

  else:
    break


v = creat_vector(t, limi, lims)
print(v)

num = 0
ach = 0


for i in range(len(v)):
  if(ach == 1):
    break
  for j in range(i+1,len(v)):
    dob = v[i] + v[i]
    if(v[j] == dob):
      num = v[i]
      dob = v[j]
      ach = 1
      break


if(ach != 0):
  print(f"Elemento {num} e seu dobro: {dob}")

else:
  print("Elementos sem dobros")
# Out:
# Diga o limite inferior: 1
# Diga um limite superior: 10
# Diga o tamanho do vetor: 20
# [3, 3, 3, 5, 3, 9, 2, 9, 7, 4, 6, 2, 5, 2, 10, 9, 4, 2, 5, 10]
# Elemento 3 e seu dobro: 6

# %% [markdown]
# ELEMENTO MAIS PROXIMO DE K(BUSCA APROXIMADA)

# %%
import random

while True:
  limi = int(input("Diga o limite inferior: "))
  lims = int(input("Diga um limite superior: "))
  t = int(input("Diga o tamanho do vetor: "))

  if(t < 0):
    t = t * -1

  if(limi > lims):
    aux = lims
    lims = limi
    limi = aux
    break

  else:
    break


v = creat_vector(t, limi, lims)
print(v)
k = random.randint(limi, lims)
print(f"Elemento k: {k}")
num = 0
pos = 0
ach = 0

for i in range (len(v)):
  if(v[i] == k):
    pos = i
    ach = 1
    break

if(ach == 1):
 print(f"Elemento {k} econtrado na posição: {i+1}")

else:
  print(f"Elemento {k} nao presente na lista")
  if(k > v[0]):
    difm = k - v[0]
    num = v[0]

  else:
    difm = v[0] - k
    num = v[0]



  for j in range(len(v)):
    if(k > v[j]):
      ma = k
      me = v[j]

    else:
      ma = v[j]
      me = k

    dif = ma - me


    if(dif < difm):
        num = v[j]
        difm = dif


    dif = 0

  print(f"Elemento mais proximo de {k}: {num}")
# Out:
# Diga o limite inferior: 1
# Diga um limite superior: 100
# Diga o tamanho do vetor: 10
# [89, 51, 58, 32, 32, 3, 29, 88, 51, 21]
# Elemento k: 28
# Elemento 28 nao presente na lista
# Elemento mais proximo de 28: 29

# %% [markdown]
# CONTANDO INVERSOES

# %%
import random

while True:
  limi = int(input("Diga o limite inferior: "))
  lims = int(input("Diga um limite superior: "))
  t = int(input("Diga o tamanho do vetor: "))

  if(t < 0):
    t = t * -1

  if(limi > lims):
    aux = lims
    lims = limi
    limi = aux
    break

  else:
    break


v = creat_vector(t, limi, lims)
print(v)


invg = 0

for i in range(len(v)):
  for j in range(i+1, len(v)):
    if(v[i] > v[j]):
      invg+=1

print(f"Numero de inversôes na lista: {invg}")
# Out:
# Diga o limite inferior: 1
# Diga um limite superior: 10
# Diga o tamanho do vetor: 10
# [2, 7, 10, 7, 10, 7, 5, 3, 2, 8]
# Numero de inversôes na lista: 23

# %% [markdown]
# DUAS LISTAS

# %%
import random

while True:
  limi = int(input("Diga o limite inferior: "))
  lims = int(input("Diga um limite superior: "))
  t = int(input("Diga o tamanho do vetor: "))

  if(t < 0):
    t = t * -1

  if(limi > lims):
    aux = lims
    lims = limi
    limi = aux
    break

  else:
    break


v = creat_vector(t, limi, lims)
a = creat_vector(t, limi, lims)
aux = []
print(v)
print(a)

for i in range(len(v)):
  for j in range(len(a)):
    if(v[i] == a[j] and v[i] not in aux):
      aux.append(v[i])



print("Elementos repetidos: ")
print(aux)
# Out:
# Diga o limite inferior: 1
# Diga um limite superior: 10
# Diga o tamanho do vetor: 10
# [3, 2, 8, 10, 9, 1, 3, 3, 6, 8]
# [2, 2, 3, 4, 10, 1, 6, 4, 8, 1]
# Elementos repetidos:
# [3, 2, 8, 10, 1, 6]
